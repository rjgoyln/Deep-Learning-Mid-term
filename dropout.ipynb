# %% [markdown]
# <a href="https://colab.research.google.com/github/rjgoyln/Deep-Learning-Mid-term/blob/main/dropout.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %cd "/content/drive/MyDrive/Colab Notebooks/Deep Learning Mid-term Programming Exam 202404"
# Out:
# /content/drive/MyDrive/Colab Notebooks/Deep Learning Mid-term Programming Exam 202404

# %%
# 匯入基本套件
import os
import random
import pandas as pd
import numpy as np
import tensorflow as tf

# 1. 設定固定的 random seed 數字
SEED = 42  # 你可以換成任何自己喜歡的數字

# 2. Python 基礎層面設定
random.seed(SEED)
os.environ['PYTHONHASHSEED'] = str(SEED)

# 3. Numpy 設定
np.random.seed(SEED)

# 4. TensorFlow 設定
tf.random.set_seed(SEED)
os.environ['TF_DETERMINISTIC_OPS'] = '1'  # (可選) 讓 TensorFlow 也盡量走固定路徑

# (選擇性) 讓 TensorFlow 日誌輸出更乾淨
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '2'  # '2' 表示只輸出 warning 和 error

# %%
# 讀取資料
air_visit = pd.read_csv('air_visit_data.csv')
air_reserve = pd.read_csv('air_reserve.csv')
hpg_reserve = pd.read_csv('hpg_reserve.csv')
store_relation = pd.read_csv('store_id_relation.csv')
air_info = pd.read_csv('air_store_info.csv')
hpg_info = pd.read_csv('hpg_store_info.csv')
date_info = pd.read_csv('date_info.csv')

# %%
# 處理 air_visit 的時間特徵
air_visit['visit_date'] = pd.to_datetime(air_visit['visit_date'])
air_visit.head()
# Out:
#            air_store_id visit_date  visitors
# 0  air_ba937bf13d40fb24 2016-01-13        25
# 1  air_ba937bf13d40fb24 2016-01-14        32
# 2  air_ba937bf13d40fb24 2016-01-15        29
# 3  air_ba937bf13d40fb24 2016-01-16        22
# 4  air_ba937bf13d40fb24 2016-01-18         6

# %%
# 處理 air_reserve 精確到小時
air_reserve['visit_datetime'] = pd.to_datetime(air_reserve['visit_datetime'])
air_reserve['reserve_datetime'] = pd.to_datetime(air_reserve['reserve_datetime'])

# 計算預約提前時間（小時）
air_reserve['reserve_diff_hours'] = (air_reserve['visit_datetime'] - air_reserve['reserve_datetime']).dt.total_seconds() / 3600

# 轉成日期格式（用於 groupby）
air_reserve['visit_date'] = air_reserve['visit_datetime'].dt.date
air_reserve['visit_date'] = pd.to_datetime(air_reserve['visit_date'])

# 聚合：每家餐廳、每天的總預約人數、平均預約人數、平均預約提前小時
air_res_agg = air_reserve.groupby(['air_store_id', 'visit_date']).agg({
    'reserve_visitors': ['sum', 'mean'],
    'reserve_diff_hours': ['mean']
}).reset_index()

# 展平成單層欄位名稱
air_res_agg.columns = ['air_store_id', 'visit_date', 'res_visitors_sum', 'res_visitors_mean', 'res_diff_hours_mean']

# 檢查前幾筆
air_res_agg.head()
# Out:
#            air_store_id visit_date  res_visitors_sum  res_visitors_mean  \
# 0  air_00a91d42b08b08d9 2016-10-31                 2                2.0
# 1  air_00a91d42b08b08d9 2016-12-05                 9                9.0
# 2  air_00a91d42b08b08d9 2016-12-14                18               18.0
# 3  air_00a91d42b08b08d9 2016-12-17                 2                2.0
# 4  air_00a91d42b08b08d9 2016-12-20                 4                4.0
#
#    res_diff_hours_mean
# 0                  4.0
# 1                100.0
# 2                153.0
# 3                147.0
# 4                 51.0

# %%
# 處理 hpg_reserve 並轉換為 air_store_id
hpg_reserve = hpg_reserve.merge(store_relation, how='inner', on='hpg_store_id')

# 轉換為 datetime 格式
hpg_reserve['visit_datetime'] = pd.to_datetime(hpg_reserve['visit_datetime'])
hpg_reserve['reserve_datetime'] = pd.to_datetime(hpg_reserve['reserve_datetime'])

# 計算預約提前時間（以小時為單位）
hpg_reserve['reserve_diff_hours'] = (hpg_reserve['visit_datetime'] - hpg_reserve['reserve_datetime']).dt.total_seconds() / 3600

# 新增 visit_date 欄位以便 groupby
hpg_reserve['visit_date'] = hpg_reserve['visit_datetime'].dt.date
hpg_reserve['visit_date'] = pd.to_datetime(hpg_reserve['visit_date'])

# 每家餐廳、每天的總預約人數、平均預約人數、平均提前時間（小時）
hpg_res_agg = hpg_reserve.groupby(['air_store_id', 'visit_date']).agg({
    'reserve_visitors': ['sum', 'mean'],
    'reserve_diff_hours': ['mean']
}).reset_index()

# 展平成單層欄位名稱
hpg_res_agg.columns = ['air_store_id', 'visit_date', 'hpg_res_visitors_sum', 'hpg_res_visitors_mean', 'hpg_res_diff_hours_mean']

# 顯示結果
hpg_res_agg.head()
# Out:
#            air_store_id visit_date  hpg_res_visitors_sum  \
# 0  air_00a91d42b08b08d9 2016-01-14                     2
# 1  air_00a91d42b08b08d9 2016-01-15                     4
# 2  air_00a91d42b08b08d9 2016-01-16                     2
# 3  air_00a91d42b08b08d9 2016-01-22                     2
# 4  air_00a91d42b08b08d9 2016-01-29                     5
#
#    hpg_res_visitors_mean  hpg_res_diff_hours_mean
# 0                    2.0                     77.0
# 1                    4.0                    142.0
# 2                    2.0                     70.0
# 3                    2.0                     82.0
# 4                    5.0                    144.0

# %%
# 處理日期資訊（假日）
date_info['calendar_date'] = pd.to_datetime(date_info['calendar_date'])
date_info = date_info.rename(columns={'calendar_date': 'visit_date'})
date_info['day_of_week'] = pd.to_datetime(date_info['visit_date']).dt.dayofweek
date_info.head()
# Out:
#   visit_date  day_of_week  holiday_flg
# 0 2016-01-01            4            1
# 1 2016-01-02            5            1
# 2 2016-01-03            6            1
# 3 2016-01-04            0            0
# 4 2016-01-05            1            0

# %%
# 合併所有資訊到 air_visit
df = air_visit.copy()
df = df.merge(air_info, how='left', on='air_store_id')
df = df.merge(air_res_agg, how='left', on=['air_store_id', 'visit_date'])
df = df.merge(hpg_res_agg, how='left', on=['air_store_id', 'visit_date'])
df = df.merge(date_info, how='left', on='visit_date')
df.to_csv('/content/my_dataframe.csv', index=False)  # 儲存為 CSV 檔案，不儲存索引
df.head()
# Out:
#            air_store_id visit_date  visitors air_genre_name  \
# 0  air_ba937bf13d40fb24 2016-01-13        25     Dining bar
# 1  air_ba937bf13d40fb24 2016-01-14        32     Dining bar
# 2  air_ba937bf13d40fb24 2016-01-15        29     Dining bar
# 3  air_ba937bf13d40fb24 2016-01-16        22     Dining bar
# 4  air_ba937bf13d40fb24 2016-01-18         6     Dining bar
#
#                   air_area_name   latitude   longitude  res_visitors_sum  \
# 0  Tōkyō-to Minato-ku Shibakōen  35.658068  139.751599               NaN
# 1  Tōkyō-to Minato-ku Shibakōen  35.658068  139.751599               NaN
# 2  Tōkyō-to Minato-ku Shibakōen  35.658068  139.751599               NaN
# 3  Tōkyō-to Minato-ku Shibakōen  35.658068  139.751599               NaN
# 4  Tōkyō-to Minato-ku Shibakōen  35.658068  139.751599               NaN
#
#    res_visitors_mean  res_diff_hours_mean  hpg_res_visitors_sum  \
# 0                NaN                  NaN                   NaN
# 1                NaN                  NaN                   NaN
# 2                NaN                  NaN                   NaN
# 3                NaN                  NaN                   NaN
# 4                NaN                  NaN                   NaN
#
#    hpg_res_visitors_mean  hpg_res_diff_hours_mean  day_of_week  holiday_flg
# 0                    NaN                      NaN            2            0
# 1                    NaN                      NaN            3            0
# 2                    NaN                      NaN            4            0
# 3                    NaN                      NaN            5            0
# 4                    NaN                      NaN            0            0

# %%
# 先確保日期排序正確
df = df.sort_values(['air_store_id', 'visit_date'])

# 建立前一天的來客數 (lag1)
df['visitors_lag1'] = df.groupby('air_store_id')['visitors'].shift(1)

# 建立過去7天的平均來客數 (rolling mean)
df['visitors_rolling7'] = df.groupby('air_store_id')['visitors'].shift(1).rolling(window=7).mean()

df['visitors_rolling30'] = df.groupby('air_store_id')['visitors'].shift(1).rolling(window=30).mean()

df.head()
# Out:
#                air_store_id visit_date  visitors  air_genre_name  \
# 87534  air_00a91d42b08b08d9 2016-07-01        35  Italian/French
# 87535  air_00a91d42b08b08d9 2016-07-02         9  Italian/French
# 87536  air_00a91d42b08b08d9 2016-07-04        20  Italian/French
# 87537  air_00a91d42b08b08d9 2016-07-05        25  Italian/French
# 87538  air_00a91d42b08b08d9 2016-07-06        29  Italian/French
#
#                          air_area_name   latitude   longitude  \
# 87534  Tōkyō-to Chiyoda-ku Kudanminami  35.694003  139.753595
# 87535  Tōkyō-to Chiyoda-ku Kudanminami  35.694003  139.753595
# 87536  Tōkyō-to Chiyoda-ku Kudanminami  35.694003  139.753595
# 87537  Tōkyō-to Chiyoda-ku Kudanminami  35.694003  139.753595
# 87538  Tōkyō-to Chiyoda-ku Kudanminami  35.694003  139.753595
#
#        res_visitors_sum  res_visitors_mean  res_diff_hours_mean  \
# 87534               NaN                NaN                  NaN
# 87535               NaN                NaN                  NaN
# 87536               NaN                NaN                  NaN
# 87537               NaN                NaN                  NaN
# 87538               NaN                NaN                  NaN
#
#        hpg_res_visitors_sum  hpg_res_visitors_mean  hpg_res_diff_hours_mean  \
# 87534                   1.0                    1.0                     29.0
# 87535                   NaN                    NaN                      NaN
# 87536                   NaN                    NaN                      NaN
# 87537                   NaN                    NaN                      NaN
# 87538                   7.0                    7.0                    278.0
#
#        day_of_week  holiday_flg  visitors_lag1  visitors_rolling7  \
# 87534            4            0            NaN                NaN
# 87535            5            0           35.0                NaN
# 87536            0            0            9.0                NaN
# 87537            1            0           20.0                NaN
# 87538            2            0           25.0                NaN
#
#        visitors_rolling30
# 87534                 NaN
# 87535                 NaN
# 87536                 NaN
# 87537                 NaN
# 87538                 NaN

# %%
# 類別特徵 Label Encoding（轉換文字成數字）
from sklearn.preprocessing import LabelEncoder

for col in ['air_genre_name', 'air_area_name']:
    le = LabelEncoder()
    df[col] = le.fit_transform(df[col])

# 填補 NaN 值（可改進）
df.fillna(-1, inplace=True)

# 顯示前幾筆看看
df.head()
# df.describe()
# Out:
#                air_store_id visit_date  visitors  air_genre_name  \
# 87534  air_00a91d42b08b08d9 2016-07-01        35               6
# 87535  air_00a91d42b08b08d9 2016-07-02         9               6
# 87536  air_00a91d42b08b08d9 2016-07-04        20               6
# 87537  air_00a91d42b08b08d9 2016-07-05        25               6
# 87538  air_00a91d42b08b08d9 2016-07-06        29               6
#
#        air_area_name   latitude   longitude  res_visitors_sum  \
# 87534             44  35.694003  139.753595              -1.0
# 87535             44  35.694003  139.753595              -1.0
# 87536             44  35.694003  139.753595              -1.0
# 87537             44  35.694003  139.753595              -1.0
# 87538             44  35.694003  139.753595              -1.0
#
#        res_visitors_mean  res_diff_hours_mean  hpg_res_visitors_sum  \
# 87534               -1.0                 -1.0                   1.0
# 87535               -1.0                 -1.0                  -1.0
# 87536               -1.0                 -1.0                  -1.0
# 87537               -1.0                 -1.0                  -1.0
# 87538               -1.0                 -1.0                   7.0
#
#        hpg_res_visitors_mean  hpg_res_diff_hours_mean  day_of_week  \
# 87534                    1.0                     29.0            4
# 87535                   -1.0                     -1.0            5
# 87536                   -1.0                     -1.0            0
# 87537                   -1.0                     -1.0            1
# 87538                    7.0                    278.0            2
#
#        holiday_flg  visitors_lag1  visitors_rolling7  visitors_rolling30
# 87534            0           -1.0               -1.0                -1.0
# 87535            0           35.0               -1.0                -1.0
# 87536            0            9.0               -1.0                -1.0
# 87537            0           20.0               -1.0                -1.0
# 87538            0           25.0               -1.0                -1.0

# %%
train_df = df[df['visit_date'] < '2017-01-01']
test_df = df[df['visit_date'] >= '2017-01-01']

features = [col for col in df.columns if col not in ['visitors', 'visit_date', 'air_store_id']]
X_train = train_df[features]
y_train = train_df['visitors']

X_test = test_df[features]
y_test = test_df['visitors']

# %%
from sklearn.preprocessing import StandardScaler

# 建立 scaler
scaler = StandardScaler()

# 對訓練集進行 fit_transform，對測試集只 transform
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# %%
# import pandas as pd

# Q1 = y_train.quantile(0.25)
# Q3 = y_train.quantile(0.75)
# IQR = Q3 - Q1

# # 設定上下限
# lower_bound = Q1 - 1.5 * IQR
# upper_bound = Q3 + 1.5 * IQR

# # 篩選非極端值資料
# mask = (y_train >= lower_bound) & (y_train <= upper_bound)
# X_train_filtered = X_train_scaled[mask]
# y_train_filtered = y_train[mask]

# %%
import tensorflow as tf
from tensorflow.keras import regularizers
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, BatchNormalization
from tensorflow.keras.optimizers import Adam

model = Sequential()
model.add(Dense(64, input_dim=X_train.shape[1], activation='relu', kernel_regularizer=regularizers.l2(1e-4)))
# model.add(BatchNormalization())
model.add(Dropout(0.2))

model.add(Dense(32, activation='relu', kernel_regularizer=regularizers.l2(1e-4)))
# model.add(BatchNormalization())
model.add(Dropout(0.2))
model.add(Dense(1))  # 回歸輸出

# 編譯模型
import tensorflow as tf
from tensorflow.keras import backend as K

def rmsle_loss(y_true, y_pred):
    # 將 y_true 和 y_pred 轉換為 float32
    y_true = tf.cast(y_true, tf.float32)
    y_pred = tf.cast(y_pred, tf.float32)

    # 把負值裁成0，避免log爆掉
    y_true = K.maximum(y_true, 0)
    y_pred = K.maximum(y_pred, 0)

    # 使用 TensorFlow 的 log1p
    first_log = tf.math.log1p(y_pred)
    second_log = tf.math.log1p(y_true)

    return K.sqrt(K.mean(K.square(first_log - second_log)))


model.compile(
    optimizer='adam',
    loss='mean_squared_error',
    metrics=[rmsle_loss]   # 可以順便把 rmsle 當成指標顯示
)

model.summary()
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential_7"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense_21 (Dense)                │ (None, 64)             │         1,024 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 64)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_22 (Dense)                │ (None, 32)             │         2,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 32)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_23 (Dense)                │ (None, 1)              │            33 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 3,137 (12.25 KB)
#  Trainable params: 3,137 (12.25 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
import matplotlib.pyplot as plt
from tensorflow.keras.callbacks import EarlyStopping

# 加上 EarlyStopping
early_stop = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)

epoch = 100
batch_size = 512
# 訓練模型並儲存訓練過程的歷史紀錄
history = model.fit(X_train_scaled, y_train, epochs=epoch, batch_size=batch_size, validation_split=0.2, callbacks=[early_stop])
# Out:
# Epoch 1/100
# 273/273 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 480.8595 - rmsle_loss: 1.5864 - val_loss: 191.7919 - val_rmsle_loss: 0.6442
# Epoch 2/100
# 273/273 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 177.3529 - rmsle_loss: 0.6684 - val_loss: 182.9999 - val_rmsle_loss: 0.6284
# Epoch 3/100
# 273/273 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 170.5334 - rmsle_loss: 0.6536 - val_loss: 178.2912 - val_rmsle_loss: 0.6196
# Epoch 4/100
# 273/273 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 166.4261 - rmsle_loss: 0.6447 - val_loss: 175.1792 - val_rmsle_loss: 0.6125
# Epoch 5/100
# 273/273 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 162.8845 - rmsle_loss: 0.6385 - val_loss: 172.9531 - val_rmsle_loss: 0.6098
# Epoch 6/100
# 273/273 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 161.7425 - rmsle_loss: 0.6350 - val_loss: 171.6263 - val_rmsle_loss: 0.6072
# Epoch 7/100
# 273/273 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 159.4325 - rmsle_loss: 0.6317 - val_loss: 170.9896 - val_rmsle_loss: 0.6044
# Epoch 8/100
# 273/273 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - loss: 159.7766 - rmsle_loss: 0.6313 - val_loss: 170.4310 - val_rmsle_loss: 0.6031
# Epoch 9/100
# 273/273 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - loss: 159.4068 - rmsle_loss: 0.6303 - val_loss: 169.6441 - val_rmsle_loss: 0.6009
# Epoch 10/100
# 273/273 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 158.6363 - rmsle_loss: 0.6282 - val_loss: 168.9494 - val_rmsle_loss: 0.6005
# Epoch 11/100
# 273/273 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 157.0921 - rmsle_loss: 0.6248 - val_loss: 168.3900 - val_rmsle_loss: 0.6003
# Epoch 12/100
# 273/273 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 158.3547 - rmsle_loss: 0.6261 - val_loss: 167.5747 - val_rmsle_loss: 0.5980
# Epoch 13/100
# 273/273 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 156.5708 - rmsle_loss: 0.6236 - val_loss: 167.7740 - val_rmsle_loss: 0.5969
# Epoch 14/100
# 273/273 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 156.5485 - rmsle_loss: 0.6234 - val_loss: 167.0015 - val_rmsle_loss: 0.5984
# Epoch 15/100
# 273/273 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 156.2584 - rmsle_loss: 0.6233 - val_loss: 166.7062 - val_rmsle_loss: 0.5980
# Epoch 16/100
# 273/273 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 154.1665 - rmsle_loss: 0.6217 - val_loss: 166.4992 - val_rmsle_loss: 0.5940
# Epoch 17/100
# 273/273 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 155.3790 - rmsle_loss: 0.6217 - val_loss: 166.0209 - val_rmsle_loss: 0.5958
# Epoch 18/100
# 273/273 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 154.9726 - rmsle_loss: 0.6203 - val_loss: 165.8116 - val_rmsle_loss: 0.5928
# Epoch 19/100
# 273/273 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 154.5820 - rmsle_loss: 0.6201 - val_loss: 165.6146 - val_rmsle_loss: 0.5928
# Epoch 20/100
# 273/273 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 154.7378 - rmsle_loss: 0.6191 - val_loss: 165.4408 - val_rmsle_loss: 0.5929
# Epoch 21/100
# 273/273 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 154.1019 - rmsle_loss: 0.6188 - val_loss: 164.8419 - val_rmsle_loss: 0.5916
# Epoch 22/100
# 273/273 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 153.8040 - rmsle_loss: 0.6183 - val_loss: 164.9524 - val_rmsle_loss: 0.5924
# Epoch 23/100
# 273/273 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 153.6961 - rmsle_loss: 0.6170 - val_loss: 164.6115 - val_rmsle_loss: 0.5905
# Epoch 24/100
# 273/273 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 153.0782 - rmsle_loss: 0.6174 - val_loss: 164.3488 - val_rmsle_loss: 0.5913
# Epoch 25/100
# 273/273 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 153.2585 - rmsle_loss: 0.6172 - val_loss: 164.1198 - val_rmsle_loss: 0.5907
# Epoch 26/100
# 273/273 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 153.0305 - rmsle_loss: 0.6164 - val_loss: 163.9322 - val_rmsle_loss: 0.5901
# Epoch 27/100
# 273/273 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 153.1255 - rmsle_loss: 0.6163 - val_loss: 163.8015 - val_rmsle_loss: 0.5895
# Epoch 28/100
# 273/273 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 152.4512 - rmsle_loss: 0.6164 - val_loss: 163.8083 - val_rmsle_loss: 0.5878
# Epoch 29/100
# 273/273 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 152.6364 - rmsle_loss: 0.6153 - val_loss: 163.6780 - val_rmsle_loss: 0.5884
# Epoch 30/100
# 273/273 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 151.6835 - rmsle_loss: 0.6151 - val_loss: 163.3179 - val_rmsle_loss: 0.5887
# Epoch 31/100
# 273/273 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 151.2150 - rmsle_loss: 0.6145 - val_loss: 163.2509 - val_rmsle_loss: 0.5863
# Epoch 32/100
# 273/273 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 151.6436 - rmsle_loss: 0.6144 - val_loss: 162.9220 - val_rmsle_loss: 0.5882
# Epoch 33/100
# 273/273 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 151.1804 - rmsle_loss: 0.6141 - val_loss: 162.4665 - val_rmsle_loss: 0.5868
# Epoch 34/100
# 273/273 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 151.4554 - rmsle_loss: 0.6136 - val_loss: 162.6754 - val_rmsle_loss: 0.5865
# Epoch 35/100
# 273/273 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 151.0236 - rmsle_loss: 0.6130 - val_loss: 162.6698 - val_rmsle_loss: 0.5865
# Epoch 36/100
# 273/273 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 151.4373 - rmsle_loss: 0.6136 - val_loss: 162.4318 - val_rmsle_loss: 0.5889
# Epoch 37/100
# 273/273 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 150.6759 - rmsle_loss: 0.6132 - val_loss: 162.2712 - val_rmsle_loss: 0.5856
# Epoch 38/100
# 273/273 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 149.7545 - rmsle_loss: 0.6118 - val_loss: 162.3438 - val_rmsle_loss: 0.5857
# Epoch 39/100
# 273/273 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - loss: 150.4490 - rmsle_loss: 0.6125 - val_loss: 162.0425 - val_rmsle_loss: 0.5830
# Epoch 40/100
# 273/273 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 150.2121 - rmsle_loss: 0.6120 - val_loss: 161.8079 - val_rmsle_loss: 0.5851
# Epoch 41/100
# 273/273 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 149.7984 - rmsle_loss: 0.6113 - val_loss: 162.0324 - val_rmsle_loss: 0.5865
# Epoch 42/100
# 273/273 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 149.2939 - rmsle_loss: 0.6114 - val_loss: 161.7352 - val_rmsle_loss: 0.5852
# Epoch 43/100
# 273/273 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 148.7242 - rmsle_loss: 0.6107 - val_loss: 161.4747 - val_rmsle_loss: 0.5847
# Epoch 44/100
# 273/273 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 148.7996 - rmsle_loss: 0.6105 - val_loss: 161.7263 - val_rmsle_loss: 0.5860
# Epoch 45/100
# 273/273 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 149.7398 - rmsle_loss: 0.6114 - val_loss: 161.3517 - val_rmsle_loss: 0.5839
# Epoch 46/100
# 273/273 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 148.1274 - rmsle_loss: 0.6092 - val_loss: 161.3778 - val_rmsle_loss: 0.5843
# Epoch 47/100
# 273/273 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 149.0724 - rmsle_loss: 0.6108 - val_loss: 161.3590 - val_rmsle_loss: 0.5856
# Epoch 48/100
# 273/273 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 148.7544 - rmsle_loss: 0.6089 - val_loss: 161.1863 - val_rmsle_loss: 0.5854
# Epoch 49/100
# 273/273 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 148.8643 - rmsle_loss: 0.6103 - val_loss: 161.7454 - val_rmsle_loss: 0.5831
# Epoch 50/100
# 273/273 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 148.5199 - rmsle_loss: 0.6094 - val_loss: 161.2308 - val_rmsle_loss: 0.5848
# Epoch 51/100
# 273/273 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 148.3521 - rmsle_loss: 0.6089 - val_loss: 161.3579 - val_rmsle_loss: 0.5855
# Epoch 52/100
# 273/273 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 147.6868 - rmsle_loss: 0.6089 - val_loss: 161.6912 - val_rmsle_loss: 0.5855
# Epoch 53/100
# 273/273 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 148.0607 - rmsle_loss: 0.6087 - val_loss: 161.3033 - val_rmsle_loss: 0.5828
# Epoch 54/100
# 273/273 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 148.0346 - rmsle_loss: 0.6084 - val_loss: 161.1762 - val_rmsle_loss: 0.5844
# Epoch 55/100
# 273/273 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 147.4383 - rmsle_loss: 0.6076 - val_loss: 160.9242 - val_rmsle_loss: 0.5847
# Epoch 56/100
# 273/273 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 147.4108 - rmsle_loss: 0.6084 - val_loss: 161.0521 - val_rmsle_loss: 0.5853
# Epoch 57/100
# 273/273 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 147.8583 - rmsle_loss: 0.6083 - val_loss: 161.3934 - val_rmsle_loss: 0.5833
# Epoch 58/100
# 273/273 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 148.1483 - rmsle_loss: 0.6084 - val_loss: 161.1300 - val_rmsle_loss: 0.5853
# Epoch 59/100
# 273/273 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: 147.2605 - rmsle_loss: 0.6078 - val_loss: 160.8409 - val_rmsle_loss: 0.5843
# Epoch 60/100
# 273/273 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 146.9119 - rmsle_loss: 0.6076 - val_loss: 160.9630 - val_rmsle_loss: 0.5847
# Epoch 61/100
# 273/273 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 147.5616 - rmsle_loss: 0.6079 - val_loss: 161.1402 - val_rmsle_loss: 0.5836
# Epoch 62/100
# 273/273 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 146.8525 - rmsle_loss: 0.6069 - val_loss: 160.9509 - val_rmsle_loss: 0.5837
# Epoch 63/100
# 273/273 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 146.7407 - rmsle_loss: 0.6071 - val_loss: 160.9725 - val_rmsle_loss: 0.5839
# Epoch 64/100
# 273/273 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 146.8453 - rmsle_loss: 0.6073 - val_loss: 160.8936 - val_rmsle_loss: 0.5840
# Epoch 65/100
# 273/273 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 147.0362 - rmsle_loss: 0.6076 - val_loss: 161.0075 - val_rmsle_loss: 0.5847
# Epoch 66/100
# 273/273 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 147.0897 - rmsle_loss: 0.6075 - val_loss: 161.1658 - val_rmsle_loss: 0.5855
# Epoch 67/100
# 273/273 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 146.9945 - rmsle_loss: 0.6076 - val_loss: 160.8671 - val_rmsle_loss: 0.5866
# Epoch 68/100
# 273/273 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 146.9681 - rmsle_loss: 0.6070 - val_loss: 161.0283 - val_rmsle_loss: 0.5868
# Epoch 69/100
# 273/273 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 145.9443 - rmsle_loss: 0.6066 - val_loss: 160.7871 - val_rmsle_loss: 0.5874
# Epoch 70/100
# 273/273 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 146.7691 - rmsle_loss: 0.6077 - val_loss: 160.7557 - val_rmsle_loss: 0.5836
# Epoch 71/100
# 273/273 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 146.7744 - rmsle_loss: 0.6073 - val_loss: 160.9413 - val_rmsle_loss: 0.5854
# Epoch 72/100
# 273/273 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 146.7245 - rmsle_loss: 0.6068 - val_loss: 160.8749 - val_rmsle_loss: 0.5849
# Epoch 73/100
# 273/273 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 146.1609 - rmsle_loss: 0.6063 - val_loss: 160.9684 - val_rmsle_loss: 0.5878
# Epoch 74/100
# 273/273 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 147.2557 - rmsle_loss: 0.6070 - val_loss: 160.9102 - val_rmsle_loss: 0.5841
# Epoch 75/100
# 273/273 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 146.6037 - rmsle_loss: 0.6077 - val_loss: 160.6143 - val_rmsle_loss: 0.5841
# Epoch 76/100
# 273/273 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 146.4766 - rmsle_loss: 0.6067 - val_loss: 160.7631 - val_rmsle_loss: 0.5856
# Epoch 77/100
# 273/273 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 145.9253 - rmsle_loss: 0.6066 - val_loss: 160.8785 - val_rmsle_loss: 0.5846
# Epoch 78/100
# 273/273 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - loss: 146.2789 - rmsle_loss: 0.6068 - val_loss: 160.5840 - val_rmsle_loss: 0.5869
# Epoch 79/100
# 273/273 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - loss: 145.9650 - rmsle_loss: 0.6066 - val_loss: 160.6288 - val_rmsle_loss: 0.5851
# Epoch 80/100
# 273/273 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 146.2293 - rmsle_loss: 0.6063 - val_loss: 160.7040 - val_rmsle_loss: 0.5864
# Epoch 81/100
# 273/273 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 145.7911 - rmsle_loss: 0.6063 - val_loss: 160.6143 - val_rmsle_loss: 0.5852
# Epoch 82/100
# 273/273 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 145.5926 - rmsle_loss: 0.6059 - val_loss: 160.7133 - val_rmsle_loss: 0.5871
# Epoch 83/100
# 273/273 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 145.7621 - rmsle_loss: 0.6065 - val_loss: 160.5353 - val_rmsle_loss: 0.5855
# Epoch 84/100
# 273/273 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 145.3375 - rmsle_loss: 0.6058 - val_loss: 160.6503 - val_rmsle_loss: 0.5846
# Epoch 85/100
# 273/273 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 145.2124 - rmsle_loss: 0.6061 - val_loss: 160.4515 - val_rmsle_loss: 0.5861
# Epoch 86/100
# 273/273 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 145.2437 - rmsle_loss: 0.6065 - val_loss: 160.7066 - val_rmsle_loss: 0.5859
# Epoch 87/100
# 273/273 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 145.6247 - rmsle_loss: 0.6068 - val_loss: 160.7861 - val_rmsle_loss: 0.5849
# Epoch 88/100
# 273/273 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 145.8152 - rmsle_loss: 0.6063 - val_loss: 160.3351 - val_rmsle_loss: 0.5847
# Epoch 89/100
# 273/273 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 145.3895 - rmsle_loss: 0.6056 - val_loss: 160.4139 - val_rmsle_loss: 0.5836
# Epoch 90/100
# 273/273 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 145.2308 - rmsle_loss: 0.6066 - val_loss: 160.4124 - val_rmsle_loss: 0.5871
# Epoch 91/100
# 273/273 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 145.1861 - rmsle_loss: 0.6059 - val_loss: 160.7124 - val_rmsle_loss: 0.5852
# Epoch 92/100
# 273/273 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 145.1442 - rmsle_loss: 0.6058 - val_loss: 160.2755 - val_rmsle_loss: 0.5847
# Epoch 93/100
# 273/273 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 144.7438 - rmsle_loss: 0.6051 - val_loss: 160.3440 - val_rmsle_loss: 0.5870
# Epoch 94/100
# 273/273 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 145.0135 - rmsle_loss: 0.6053 - val_loss: 160.4227 - val_rmsle_loss: 0.5869
# Epoch 95/100
# 273/273 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 145.5731 - rmsle_loss: 0.6069 - val_loss: 160.4737 - val_rmsle_loss: 0.5871
# Epoch 96/100
# 273/273 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 144.7564 - rmsle_loss: 0.6058 - val_loss: 160.3797 - val_rmsle_loss: 0.5849
# Epoch 97/100
# 273/273 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 144.2877 - rmsle_loss: 0.6053 - val_loss: 160.3309 - val_rmsle_loss: 0.5855
# Epoch 98/100
# 273/273 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - loss: 144.3330 - rmsle_loss: 0.6053 - val_loss: 160.0422 - val_rmsle_loss: 0.5859
# Epoch 99/100
# 273/273 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - loss: 145.2559 - rmsle_loss: 0.6058 - val_loss: 160.2816 - val_rmsle_loss: 0.5862
# Epoch 100/100
# 273/273 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 145.6971 - rmsle_loss: 0.6060 - val_loss: 160.5569 - val_rmsle_loss: 0.5858

# %%
y_pred = model.predict(X_test_scaled)

from sklearn.metrics import mean_absolute_error, mean_squared_error
import numpy as np
mse = mean_squared_error(y_test, y_pred)
rmse = np.sqrt(mse)
# Out:
# 2425/2425 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step

# %%
stopped_epoch = early_stop.stopped_epoch
if stopped_epoch > 0:
    print(f"Early stopping triggered at epoch {stopped_epoch + 1}/{epoch}")
else:
    print(f"Early stopping was not triggered. {epoch}/{epoch}")

print(f"batch size: {batch_size}")

print("- - - - - - - - - - - - - - - - - - - - - - -")
# train result
print("loss function: " + model.loss)
print(f"train loss(correspond to best val): {loss[best_epoch]:.4f}")
print(f"best val loss: {best_val_loss:.4f}")

print("- - - - - - - - - - - - - - - - - - - - - - -")
# test result
print(f"Test MSE: {mse:.4f}")

# mean_visitors = y_test.mean()
# print(f"Relative RMSE: {(rmse / mean_visitors) * 100:.2f}%")

# RMSLE
import numpy as np

def rmsle(y_true, y_pred):
    # 把負數裁成0，避免 log 出現錯誤
    y_true = np.maximum(0, y_true)
    y_pred = np.maximum(0, y_pred)

    # 計算 RMSLE
    return np.sqrt(np.mean((np.log1p(y_true) - np.log1p(y_pred)) ** 2))

# 用你的 y_test, y_pred 計算
rmsle_score = rmsle(y_test, y_pred.flatten())

print(f"Test RMSLE: {rmsle_score:.4f}")
# Out:
# Early stopping was not triggered. 100/100
# batch size: 512
# - - - - - - - - - - - - - - - - - - - - - - -
# loss function: mean_squared_error
# train loss(correspond to best val): 141.0208
# best val loss: 160.0422
# - - - - - - - - - - - - - - - - - - - - - - -
# Test MSE: 183.1448
# Test RMSLE: 0.5939

# %%
import numpy as np
import matplotlib.pyplot as plt

# 取出歷史紀錄
loss = history.history['loss']
val_loss = history.history['val_loss']

# x軸從1開始
epochs = range(1, len(loss) + 1)

# 找到最佳 Early Stopping 的 epoch
best_epoch = early_stop.stopped_epoch - early_stop.patience
best_val_loss = min(val_loss)

# 畫圖
plt.figure(figsize=(8, 6))
plt.plot(epochs, loss, label='Train Loss', linewidth=2)
plt.plot(epochs, val_loss, label='Validation Loss', linewidth=2)

# 標記 EarlyStopping 發生的位置
plt.axvline(x=best_epoch + 1, color='red', linestyle='--', label=f'Early Stopping at epoch {best_epoch + 1}')
plt.scatter(best_epoch + 1, best_val_loss, color='red')

# x軸每5個顯示一個
plt.xticks(np.arange(0, len(loss)+5, 5))  # 0到最大epoch，每5步一個tick

plt.title('Training and Validation Loss', fontsize=16)
plt.xlabel('Epoch', fontsize=12)
plt.ylabel('Loss', fontsize=12)
plt.legend()
plt.grid(True, linestyle='--', alpha=0.5)
plt.tight_layout()
plt.show()

# %%
test_dates = df.loc[X_test.index, 'visit_date']
result_df = pd.DataFrame({'date': test_dates, 'actual': y_test, 'predicted': y_pred.flatten()})
result_df = result_df.sort_values('date')

import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(16, 6))

# 畫實際值（實線）
sns.lineplot(data=result_df, x='date', y='actual', label='Actual Visitors',
             linewidth=2.2, color='royalblue', errorbar=None)

# 畫預測值（虛線）
sns.lineplot(data=result_df, x='date', y='predicted', label='Predicted Visitors',
             linewidth=2.2, color='#e67e22', linestyle='--', errorbar=None)

# 美化
plt.title("Actual vs Predicted Visitors Over Time", fontsize=16)
plt.xlabel("Date", fontsize=12)
plt.ylabel("Number of Visitors", fontsize=12)
plt.xticks(rotation=45)
plt.grid(True, linestyle='--', alpha=0.3)
plt.legend(fontsize=12)
plt.tight_layout()

plt.show()

# %%
# 看一下誤差分布
result_df['error'] = result_df['predicted'] - result_df['actual']
plt.figure(figsize=(8, 6))
plt.hist(result_df['error'], bins=100, color='skyblue', edgecolor='blue')
plt.title("Prediction Error Distribution")
plt.xlabel("Prediction Error")
plt.ylabel("Frequency")
plt.ylim(0, 200)  # 限制橫軸範圍
#　plt.xlim(-100, 100)
plt.grid(True)
plt.show()
print(y_test.shape)
# Out:
# (77573,)
